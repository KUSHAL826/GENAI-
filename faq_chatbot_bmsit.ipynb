# %%
# !pip install -q -U google-genai

# %%
from google import genai
from google.genai import types
from google.colab import userdata

client=genai.Client(api_key=userdata.get("GEMINI_API_KEYS"))
MODEL="gemini-3.5-flash-lite"

# %%
knowledge_base="""
BMSIT&M DETAILED FAQ KNOWLEDGE BASE

Q1: What is BMSIT&M?
A: BMS Institute of Technology & Management (BMSIT&M) is an engineering and technology institute located in Bengaluru, Karnataka.

Q2: What does BMSIT&M stand for?
A: BMSIT&M stands for BMS Institute of Technology & Management.

Q3: Where is BMSIT&M located?
A: BMSIT&M is located in Bengaluru, Karnataka, India.

Q4: What type of institution is BMSIT&M?
A: BMSIT&M is an engineering and technology institution offering undergraduate and postgraduate programs.

Q5: Is BMSIT&M an autonomous institution?
A: Yes, BMSIT&M is an autonomous institution.

Q6: Is BMSIT&M affiliated with VTU?
A: Yes, BMSIT&M is an autonomous institution affiliated with Visvesvaraya Technological University (VTU).

Q7: What is an autonomous college?
A: An autonomous college has academic freedom to design its curriculum, conduct examinations, and follow its own academic regulations within the framework of its affiliating university and regulatory requirements.

Q8: Does BMSIT&M offer undergraduate programs?
A: Yes, BMSIT&M offers undergraduate engineering and technology programs.

Q9: Does BMSIT&M offer postgraduate programs?
A: Yes, BMSIT&M offers postgraduate programs in selected engineering and technology areas.

Q10: Does BMSIT&M offer Computer Science and Engineering?
A: Yes, BMSIT&M offers a Computer Science and Engineering program.

Q11: What engineering branches are available at BMSIT&M?
A: BMSIT&M offers programs in areas such as Computer Science and Engineering, Information Science and Engineering, Electronics and Communication Engineering, Artificial Intelligence and Machine Learning, and other engineering disciplines.

Q12: Does BMSIT&M offer Information Science and Engineering?
A: Yes, Information Science and Engineering is one of the engineering areas offered by the institute.

Q13: Does BMSIT&M offer Electronics and Communication Engineering?
A: Yes, Electronics and Communication Engineering is one of the engineering areas offered by the institute.

Q14: Does BMSIT&M offer Artificial Intelligence and Machine Learning?
A: Yes, BMSIT&M offers a program in Artificial Intelligence and Machine Learning.

Q15: Where can I find information about the courses offered by BMSIT&M?
A: Students should refer to the official BMSIT&M information for the current list of courses and programs.

Q16: Where can I find admission information?
A: Students should refer to the official BMSIT&M admission information and the applicable entrance-examination or counselling authority for current admission procedures.

Q17: How can I find the current admission procedure?
A: The current admission procedure should be checked through the official BMSIT&M admission information and the applicable entrance-examination or counselling authority.

Q18: Does BMSIT&M have placement activities?
A: Yes, BMSIT&M has a placement and training system that helps students prepare for employment opportunities and campus recruitment.

Q19: What does the placement and training system do?
A: It helps students prepare for employment opportunities and campus recruitment.

Q20: Does BMSIT&M provide placement preparation?
A: Yes, the placement and training system supports students in preparing for employment opportunities and campus recruitment.

Q21: Does BMSIT&M support student projects?
A: Yes, students can work on academic, technical, research, and innovation-oriented projects as part of their learning.

Q22: Can students participate in technical competitions?
A: Yes, students can participate in technical competitions, hackathons, project exhibitions, and other innovation-related events.

Q23: Can students participate in hackathons?
A: Yes, students can participate in hackathons as part of technical and innovation-related activities.

Q24: Can students participate in project exhibitions?
A: Yes, students can participate in project exhibitions and other innovation-related events.

Q25: What extracurricular activities are available?
A: Students can participate in technical events, workshops, competitions, student clubs, cultural activities, sports, and other extracurricular activities.

Q26: Does BMSIT&M have student clubs?
A: Yes, students can participate in student clubs and other extracurricular activities.

Q27: Does BMSIT&M conduct technical workshops?
A: Yes, students can participate in technical workshops and technical events.

Q28: Can students participate in cultural activities?
A: Yes, cultural activities are among the extracurricular activities available to students.

Q29: Can students participate in sports?
A: Yes, sports are among the extracurricular activities available to students.

Q30: What facilities does BMSIT&M provide?
A: The institute provides academic and campus facilities such as classrooms, laboratories, library resources, computing facilities, and other student-support facilities.

Q31: Does BMSIT&M have laboratories?
A: Yes, laboratories are among the academic facilities provided by the institute.

Q32: Does BMSIT&M have a library?
A: Yes, library resources are among the facilities provided by the institute.

Q33: Does BMSIT&M provide computing facilities?
A: Yes, computing facilities are among the academic and campus facilities provided by the institute.

Q34: Does BMSIT&M support research?
A: Students can work on research-oriented projects as part of their academic and innovation activities.

Q35: Does BMSIT&M support innovation?
A: Yes, students can participate in innovation-oriented projects, hackathons, project exhibitions, and other related activities.

Q36: Can students work on academic projects?
A: Yes, students can work on academic projects as part of their learning.

Q37: Can students work on technical projects?
A: Yes, students can work on technical projects as part of their academic and innovation activities.

Q38: Can students participate in research projects?
A: Yes, students can work on research-oriented projects.

Q39: Does BMSIT&M provide student support facilities?
A: Yes, the institute provides other student-support facilities in addition to its academic and campus facilities.

Q40: How can I get the latest information about BMSIT&M?
A: For current information about admissions, fees, courses, academic schedules, placements, and other official matters, students should check the official BMSIT&M website or contact the institute directly.

Q41: Where should I check current fee information?
A: Students should check the official BMSIT&M information for current fee details.

Q42: Where should I check the current academic schedule?
A: Students should refer to the official BMSIT&M information for the current academic schedule.

Q43: Where should I check the latest placement information?
A: Students should refer to the official BMSIT&M placement information for current placement details.

Q44: Where can students get official information about BMSIT&M?
A: Students should refer to the official BMSIT&M website or contact the institute directly for official and current information.

Q45: Can the chatbot provide information that is not present in this FAQ?
A: No. The chatbot should answer only using the information available in this knowledge base. If the required information is not covered, it should state that it does not have that information and direct the user to the official BMSIT&M source.

Q46: What should the chatbot do if a student asks about fees that are not mentioned in the knowledge base?
A: The chatbot should not guess or provide an estimated fee. It should state that the information is not available in the knowledge base and direct the student to the official BMSIT&M source.

Q47: What should the chatbot do if a student asks an unrelated question?
A: The chatbot should politely explain that it can only help with BMSIT&M-related queries.

Q48: What should the chatbot do if a student asks about another college?
A: The chatbot should politely explain that it can only help with BMSIT&M-related queries.

Q49: What should the chatbot do if a student asks for information that is not covered?
A: The chatbot should not make up an answer. It should use the specified fallback response and direct the student to the official BMSIT&M source.

Q50: Should the chatbot make assumptions about BMSIT&M?
A: No. The chatbot must answer only from the provided knowledge base and should never invent policies, fees, admission requirements, facilities, schedules, placement statistics, or other information.
"""

system_instruction=f"""
Your BMSIT assitant,so reply with "Welcome to BMSIT,i am your assistant to explore BMSIT" whenever new session starts.
Refer to Knowledge provided related to BMSIT in {knowledge_base} and answer to queries asked by user.

1. Answer ONLY using the information in the KNOWLEDGE BASE below.

2. If a question is NOT covered, reply exactly:
   "I'm sorry, I don't have that information. Please visit the official BMSIT&M website or contact the college administration for assistance."

3. NEVER make up information about BMSIT&M, including fees, admissions, courses, placements, timings, facilities, policies, or contact details.

4. Be polite, warm, and concise. Reply in 1-3 sentences.

5. Address the user respectfully — use "you" naturally and keep the tone friendly, not overly formal.

6. If the user asks about other colleges, unrelated topics, or anything outside BMSIT&M, politely steer back:
   "I can only help with BMSIT&M-related queries."
"""

chat=client.chats.create(
    model=MODEL,
    config=types.GenerateContentConfig(
        system_instruction=system_instruction,
        temperature=0.4,
        max_output_tokens=1000,
        thinking_config=types.ThinkingConfig(thinking_level='low')
    ),
    history=[]
)
print("CHAT BOT STARTING..........\nSTARTED")

while True:
  user_input=input("Enter your query (exit/bye/quit to exit from chatbot)\nUSER: ")
  if user_input.lower() in ['exit','bye','quit']:
    print("CHAT BOT EXITING..........\nEXITED")
    break
  response=chat.send_message(user_input)
  print(f"ASSITANT:{response.text}")
# Out:
# CHAT BOT STARTING..........
# STARTED
# Enter your query (exit/bye/quit to exit from chatbot)
# USER: hi
# ASSITANT:Welcome to BMSIT, i am your assistant to explore BMSIT. How can I help you today?
# Enter your query (exit/bye/quit to exit from chatbot)
# USER: i completed 2nd puc and looking for technical courses
# ASSITANT:BMSIT&M offers undergraduate engineering and technology programs, including Computer Science and Engineering, Information Science and Engineering, Electronics and Communication Engineering, and Artificial Intelligence and Machine Learning. You should refer to the official BMSIT&M website or contact the institute directly for current admission information and course details.
# Enter your query (exit/bye/quit to exit from chatbot)
# USER: CSE i need
# ...
