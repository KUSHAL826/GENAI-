# %%
# !pip install -q -U google-genai

# %%
from google import genai
from google.colab import userdata
from google.genai import types
import numpy as np

client=genai.Client(api_key=userdata.get("GEMINI_API_KEYS"))
MODEL="gemini-3.5-flash-lite"
EMB_MODEL="gemini-embedding-001"
EMB_DIM=768

# %%
faq= {
    "How do I reset my company account password?":
        "To reset your company account password, open the employee login portal and select 'Forgot Password'. Follow the verification steps sent to your registered email or phone number and create a new password.",

    "I forgot my corporate login password. How can I change it?":
        "If you forgot your corporate login password, select 'Forgot Password' on the login page. Verify your identity using the registered contact details and set a new password.",

    "What should I do if my employee account is locked?":
        "If your employee account is locked, wait for the specified lockout period or contact the IT help desk to verify your identity and request an account unlock.",

    "Why can't I log in to the company portal?":
        "If you cannot log in to the company portal, first verify your username and password. If the problem continues, check your account status or contact the IT help desk.",

    "How can I unlock my enterprise account?":
        "To unlock your enterprise account, use the account recovery option on the login portal or contact IT support if self-service recovery is unavailable.",

    "How do I access my company email?":
        "You can access your company email through the organization's approved webmail portal or email application using your corporate credentials.",

    "Why am I not receiving emails on my corporate account?":
        "If you are not receiving corporate emails, check your internet connection, spam folder, mailbox storage, and email filters. Contact IT support if the issue continues.",

    "How can I configure my company email on my phone?":
        "To configure company email on your phone, install the organization's approved email application and sign in using your corporate email address and credentials.",

    "How do I connect to the company VPN?":
        "To connect to the company VPN, install the organization's approved VPN client, enter your corporate credentials, complete MFA verification, and connect to the company network.",

    "Why is my VPN connection not working?":
        "If your VPN is not working, check your internet connection, restart the VPN client, and verify your credentials. If the problem persists, contact IT support.",

    "How can I access company resources while working from home?":
        "To access company resources while working from home, connect your company-approved device to the corporate VPN and use your normal enterprise credentials.",

    "How can I request a new company laptop?":
        "To request a new company laptop, submit a hardware request through the organization's IT service portal and provide the required business justification and manager approval.",

    "What should I do if my company laptop is not turning on?":
        "If your company laptop does not turn on, connect it to a power source, check the charger, and try restarting it. If it still does not start, contact IT support.",

    "How do I request access to enterprise software?":
        "To request access to enterprise software, submit an application-access request through the company's IT service portal. Approval may be required from your manager or application owner.",

    "Why can't I access a particular company application?":
        "If you cannot access a company application, verify that your account has the required permissions and that the application is available. Contact IT support if the problem continues.",

    "How can I apply for annual leave?":
        "To apply for annual leave, open the company's HR portal, select the leave application option, choose the required dates, and submit the request for approval.",

    "Where can I check my remaining leave balance?":
        "You can check your remaining leave balance by signing in to the company's HR portal and opening the leave or attendance section.",

    "How do I update my personal information in the HR portal?":
        "To update your personal information, sign in to the HR portal and edit the information available for employee self-service. Contact HR if a field cannot be changed directly.",

    "How can I download my salary slip?":
        "To download your salary slip, sign in to the employee HR or payroll portal, open the payslip section, select the required month, and download the available document.",

    "How do I mark my attendance?":
        "To mark your attendance, sign in to the company's approved attendance system and use the check-in or attendance option according to the organization's attendance policy.",

    "What should I do if I forgot to check in?":
        "If you forgot to check in, submit an attendance correction request through the attendance system or contact your manager or HR according to company policy.",

    "When will my monthly salary be credited?":
        "Monthly salary is normally credited according to the company's published payroll schedule. Check the payroll calendar or contact HR or payroll for the exact payment date.",

    "Why has my salary not been credited yet?":
        "If your salary has not been credited, first check the published payroll date and your bank account. If the payment is still missing after the expected date, contact the payroll department.",

    "How do I report a suspicious email?":
        "To report a suspicious email, do not click links or open attachments. Use the company's approved phishing-reporting option or contact the designated security team.",

    "What should I do if I think my account has been compromised?":
        "If you believe your account has been compromised, immediately contact IT or the security team, change your password if possible, and follow the organization's security instructions.",

    "How can I enable multi-factor authentication?":
        "To enable multi-factor authentication, open the company's approved security or account settings and follow the instructions to register an authenticator application or another approved verification method.",

    "How do I submit a business expense claim?":
        "To submit a business expense claim, sign in to the company's expense management system, enter the expense details, attach valid receipts, and submit the claim for approval.",

    "What expenses are eligible for reimbursement?":
        "Eligible expenses are determined by the company's travel and expense policy. Review the approved expense categories and limits before submitting a reimbursement claim.",

    "How can I check the status of my expense claim?":
        "You can check the status of an expense claim by signing in to the company's expense management system and opening the submitted claims or reimbursement section."
}
def embed(text):
  response=client.models.embed_content(
      model=EMB_MODEL,
      contents=text,
      config=types.EmbedContentConfig(
          output_dimensionality=EMB_DIM
      )
  )
  return response.embeddings[0].values
def cosine_sim(a,b):
  a=np.array(a)
  b=np.array(b)

  return (np.dot(a,b))/(np.linalg.norm(a)*np.linalg.norm(b))


embeddings=np.array([
    embed(sentence)
    for sentence in faq.keys()
])
user_input=input("Enter the query: ")
user_embed=embed(user_input)
similarity=[]
for i,embedding in enumerate(embeddings):
  score=cosine_sim(user_embed,embedding)
  similarity.append((i,score))
best_index,best_score=max(similarity,key=lambda x:x[1])
question=list(faq.keys())[best_index]
answer=faq[question]
print(f"NEAREST FAQ FOUND:{question}")
print(f"BOT:{answer} ")
# Out:
# Enter the query: I forgot my password
# NEAREST FAQ FOUND:How do I reset my company account password?
# BOT:To reset your company account password, open the employee login portal and select 'Forgot Password'. Follow the verification steps sent to your registered email or phone number and create a new password.
